# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13048\2427701451.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
sns.set_style('whitegrid')

import warnings
warnings.filterwarnings("ignore")

# %%
url = 'https://raw.githubusercontent.com/Tiamiyu1/Simplistic-Approach-to-Machine-Learning-Modeling-with-Linear-Regression/main/student.csv'
data = pd.read_csv(url)
data.head(3)
# Out:
#   FIRST NAME LAST NAME  GENDER  MATH  ENGLISH  BIOLOGY  ECONOMICS  AGRIC  \
# 0     ATTAH      OPPOR    MALE    75   100.00    100.0         55   77.0
# 1      IMRAN     ROFID  FEMALE    70    33.33    100.0         55   97.5
# 2      JAMES     WALLY    MALE    80     0.00     85.0         68  100.0
#
#    INTELIGENCE
# 0         7.61
# 1         7.73
# 2         7.72

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FIRST NAME   26 non-null     object
#  1   LAST NAME    26 non-null     object
#  2   GENDER       26 non-null     object
#  3   MATH         26 non-null     int64
#  4   ENGLISH      26 non-null     float64
#  5   BIOLOGY      26 non-null     float64
#  6   ECONOMICS    26 non-null     int64
#  7   AGRIC        26 non-null     float64
#  8   INTELIGENCE  26 non-null     float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 2.0+ KB

# %%
data.describe()
# Out:
#              MATH     ENGLISH     BIOLOGY   ECONOMICS       AGRIC  INTELIGENCE
# count   26.000000   26.000000   26.000000   26.000000   26.000000    26.000000
# mean    80.000000   74.487308   77.692308   71.115385   62.500000     6.944615
# std     23.664319   24.238665   22.901125   19.089949   26.835797     1.488122
# min      0.000000    0.000000    0.000000   35.000000   14.500000     4.080000
# 25%     75.000000   60.832500   65.000000   56.000000   50.625000     6.200000
# 50%     85.000000   78.335000   80.000000   70.000000   67.250000     7.210000
# 75%    100.000000   95.835000   97.500000   84.500000   79.500000     7.745000
# max    100.000000  100.000000  100.000000  100.000000  100.000000     9.720000

# %%
data.columns
# Out:
# Index(['FIRST NAME', 'LAST NAME', 'GENDER', 'MATH', 'ENGLISH', 'BIOLOGY',
#        'ECONOMICS', 'AGRIC', 'INTELIGENCE'],
#       dtype='object')

# %%
data.shape
# Out:
# (26, 9)

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# FIRST NAME     0.0
# LAST NAME      0.0
# GENDER         0.0
# MATH           0.0
# ENGLISH        0.0
# BIOLOGY        0.0
# ECONOMICS      0.0
# AGRIC          0.0
# INTELIGENCE    0.0
# dtype: float64

# %%
#check for any duplicated entries
data.duplicated().any()
# Out:
# False

# %%
data.dtypes
# Out:
# FIRST NAME      object
# LAST NAME       object
# GENDER          object
# MATH             int64
# ENGLISH        float64
# BIOLOGY        float64
# ECONOMICS        int64
# AGRIC          float64
# INTELIGENCE    float64
# dtype: object

# %%
#uniques value
data['GENDER'].unique()
data['FIRST NAME'].nunique()
data['GENDER'].nunique()
# Out:
# 2

# %%
# gives the clount of unique values in a selected column
data['GENDER'].value_counts()
# Out:
# GENDER
# MALE      15
# FEMALE    11
# Name: count, dtype: int64

# %%
data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data.corr()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
# ...

# %%
sns.countplot(data.GENDER)
# Out:
# <Axes: xlabel='count', ylabel='GENDER'>

# %%
sns.boxplot(x='GENDER', y='INTELIGENCE', data=data)
# Out:
# <Axes: xlabel='GENDER', ylabel='INTELIGENCE'>

# %%
sns.histplot(data.INTELIGENCE, kde= True)
# Out:
# <Axes: xlabel='INTELIGENCE', ylabel='Count'>

# %%
sns.lineplot(x='AGRIC', y='INTELIGENCE',data=data)
# Out:
# <Axes: xlabel='AGRIC', ylabel='INTELIGENCE'>

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.heatmap(data.corr(),annot=True)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
# ...

# %%
sns.pairplot(data)
